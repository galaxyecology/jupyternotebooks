# %%
os.system("conda install matplotlib")
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - bioconda
# Platform: linux-64
# ...
# Solving environment: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 25.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     brotli-1.1.0               |       hb9d3cd8_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hb9d3cd8_2          18 KB  conda-forge
#     ca-certificates-2025.8.3   |       hbd8a1cb_0         151 KB  conda-forge
#     certifi-2025.8.3           |     pyhd8ed1ab_0         155 KB  conda-forge
# ...

# %%
import numpy as np
from numpy.polynomial import Polynomial
import matplotlib.pyplot as plt

# %%
os.system("mv galaxy_inputs/input/*  galaxy_inputs/input/input.csv")
# Out:
# inputcsv.csv
# 0

# %%
coeff_f = 'galaxy_inputs/input/input.csv' # oda:POSIXPath
min_ = -2 # oda:Float; oda:label "Left bound of x-axis"
max_ = 4 # oda:Float; oda:label "Right bound of x-axis"
ymin = None # oda:Float, oda:optional; oda:label "Lower bound of y-axis" 
ymax = None # oda:Float, oda:optional; oda:label "Upper bound of y-axis"

# %%
coeff = np.genfromtxt(coeff_f, delimiter=',')

p = Polynomial(coeff)

# %%
x = np.linspace(min_, max_, 1000)
plt.figure(figsize=(5, 4))
im = plt.plot(x, p(x), label=f"{p}")
plt.xlabel("x")
plt.legend()
plt.ylim(ymin, ymax)

plt.savefig('./outputs/plot.png')

# %%
function_plot = './outputs/plot.png' 
roots = list(p.roots())
